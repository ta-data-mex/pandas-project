# %%
import os
import openpyxl
import numpy as np
import pandas as pandito
import pymongo
from pymongo import MongoClient
import dnspython
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-cb6d7d8ea24c> in <module>
#       5 import pymongo
#       6 from pymongo import MongoClient
# ----> 7 import dnspython
#
# ModuleNotFoundError: No module named 'dnspython'

# %%
#print(excel)

# %%
# connect to database
connection = MongoClient("mongodb+srv://Fer_werito:f#R2006630324@cluster0-viwq6.mongodb.net/test?retryWrites=true&w=majority")
db = connection.actas
coleccion = db.concentrado

# %%
print(connection)
print(db)
print(coleccion)
# Out:
# MongoClient(host=['cluster0-shard-00-00-viwq6.mongodb.net:27017', 'cluster0-shard-00-02-viwq6.mongodb.net:27017', 'cluster0-shard-00-01-viwq6.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True, w='majority')
# Database(MongoClient(host=['cluster0-shard-00-00-viwq6.mongodb.net:27017', 'cluster0-shard-00-02-viwq6.mongodb.net:27017', 'cluster0-shard-00-01-viwq6.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True, w='majority'), 'actas')
# Collection(Database(MongoClient(host=['cluster0-shard-00-00-viwq6.mongodb.net:27017', 'cluster0-shard-00-02-viwq6.mongodb.net:27017', 'cluster0-shard-00-01-viwq6.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True, w='majority'), 'actas'), 'concentrado')

# %%
excel = [archivo for archivo in os.listdir("./") if archivo.endswith(".xlsx") or archivo.endswith(".xlsm")]
for archivo in excel:
    wb = openpyxl.load_workbook(archivo)
    sheet=wb.get_sheet_by_name('Hoja1')
    materia= {'Plantel':'', 'Licenciatura': '', 'Profesor':'', 'Asignatura':'', 'Clave':'', 'Grupo':'', 'alumnos':''}
    alumnos={'Matricula':'','Alumno':'','1ero':'','2do':'','3ero':'','cualitativo':'', 'Promedio':''}
    for col in range(1, sheet.max_column):
        for row in range(1, sheet.max_row):
            if (sheet.cell(row=row, column=col).value == 'Licenciatura')or (sheet.cell(row=row, column=col).value == 'Profesor')or (sheet.cell(row=row, column=col).value == 'Asignatura')or (sheet.cell(row=row, column=col).value == 'Clave') or (sheet.cell(row=row, column=col).value == 'Grupo'):
                materia[sheet.cell(row=row, column=col).value]= sheet.cell(row=row, column=col+2).value
    for row in range(7, sheet.max_row):
        alumno = str(sheet.cell(row=row, column=1).value)
        if(alumno.isdigit()==True):
            alumnos['Matricula'] = sheet.cell(row=row, column=2).value
            alumnos['Alumno'] = sheet.cell(row=row, column=3).value
            primero =sheet.cell(row=row, column=4).value
            if (primero==None):
                alumnos['1ero'] = 0.0
            else:
                alumnos['1ero'] = float(sheet.cell(row=row, column=4).value)
            segundo =sheet.cell(row=row, column=5).value
            if (segundo==None):
                alumnos['2do'] = 0.0
            else:
                alumnos['2do'] = float(sheet.cell(row=row, column=5).value)
            tercero =sheet.cell(row=row, column=6).value
            if (tercero==None):
                alumnos['3ero'] = 0.0
            else:
                alumnos['3ero'] = float(sheet.cell(row=row, column=6).value)
            cualitativo =sheet.cell(row=row, column=7).value
            if (cualitativo==None):
                alumnos['cualitativo'] = 0.0
            else:
                alumnos['cualitativo'] = float(sheet.cell(row=row, column=7).value)

            alumnos['Licenciatura'] = materia.get('Licenciatura')
            alumnos['Profesor'] = materia.get('Profesor')
            alumnos['Asignatura'] = materia.get('Asignatura')
            alumnos['Grupo'] = materia.get('Grupo')
            promedio= (alumnos.get('1ero')+alumnos.get('2do')+alumnos.get('3ero'))/3+alumnos.get('cualitativo')
            if (promedio<6):
                alumnos['Promedio'] = 5.0
            else:
                alumnos['Promedio']=float(np.rint(promedio))
            try:
                coleccion.insert_one(alumnos.copy())
                print("exito con la inserción", alumnos.copy())
            except Exception as e:
                print ("Error inesperado:", type(e), e)

query = {'Grupo':materia.get('Grupo'), 'Asignatura':alumnos.get('Asignatura')}
materia['alumnos'] = sheet.max_row-7
resultado = coleccion.find(query).count()
print(materia)
print("leidos de la hoja: ",sheet.max_row-7)
print("Insertados: ",resultado)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   after removing the cwd from sys.path.
# exito con la inserción {'Matricula': 'ZL1-904-247', 'Alumno': 'ACOSTA BELTRAN JANETH', '1ero': 8.63, '2do': 10.0, '3ero': 0.0, 'cualitativo': 0.0, 'Promedio': 6.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-151', 'Alumno': 'Medina Arteaga Edgar Raul', '1ero': 8.83, '2do': 2.0, '3ero': 0.0, 'cualitativo': 0.0, 'Promedio': 5.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-235', 'Alumno': 'ARELLANO SANCHEZ ATHZIRI YURITZI', '1ero': 8.23, '2do': 9.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-006', 'Alumno': 'BUENO VILLEDA GUADALUPE MARLENE', '1ero': 8.0, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-182', 'Alumno': 'CASTAÑEDA HERNANDEZ DIEGO', '1ero': 8.0, '2do': 7.0, '3ero': 8.0, 'cualitativo': 0.0, 'Promedio': 8.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-166', 'Alumno': 'CASTRO PEREZ IVAN', '1ero': 8.03, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-180', 'Alumno': 'CRUZ SANCHEZ HECTOR IVAN', '1ero': 8.23, '2do': 8.0, '3ero': 0.0, 'cualitativo': 0.0, 'Promedio': 5.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-153', 'Alumno': 'DE LA LUZ ESTRADA JIMENA', '1ero': 8.46, '2do': 10.0, '3ero': 7.6, 'cualitativo': 1.0, 'Promedio': 10.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-159', 'Alumno': 'DE LA O ALCAZAR CHRISTIAN ALEJANDRO', '1ero': 5.66, '2do': 7.0, '3ero': 8.0, 'cualitativo': 0.0, 'Promedio': 7.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-218', 'Alumno': 'FLORES LIMON BRANDON ISRAEL', '1ero': 8.73, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 10.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-165', 'Alumno': 'GARCIA ESLAVA MARYJOSE', '1ero': 7.7, '2do': 8.0, '3ero': 8.0, 'cualitativo': 0.0, 'Promedio': 8.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-232', 'Alumno': 'GARCIA PEREZ FERNANDO', '1ero': 8.36, '2do': 8.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-169', 'Alumno': 'GARCIA PIÑA BRISA GUADALUPE', '1ero': 8.66, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 10.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-162', 'Alumno': 'GONZALEZ ARRIAGA JOANA YARETH', '1ero': 7.56, '2do': 8.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-257', 'Alumno': 'GONZALEZ ROMAN BLANCA ESTEFANY', '1ero': 8.66, '2do': 9.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-234', 'Alumno': 'Meza Aldaco Nanci Azucena', '1ero': 0.0, '2do': 0.0, '3ero': 0.0, 'cualitativo': 0.0, 'Promedio': 5.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-214', 'Alumno': 'GUERRERO PEDROZA VIANEY', '1ero': 8.43, '2do': 8.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-215', 'Alumno': 'GUTIERREZ HERRERA ERICK ADONAIS', '1ero': 9.8, '2do': 5.0, '3ero': 7.6, 'cualitativo': 0.0, 'Promedio': 7.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-176', 'Alumno': 'HERNANDEZ DIAZ SAUL', '1ero': 9.26, '2do': 8.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-174', 'Alumno': 'HERNANDEZ TORRES CARMELO ISRAEL', '1ero': 8.13, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-168', 'Alumno': 'Gomez Zamudio Janeth Michell', '1ero': 9.06, '2do': 8.0, '3ero': 0.0, 'cualitativo': 0.0, 'Promedio': 5.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-172', 'Alumno': 'MALDONADO MONTOYA BETSABE BERENICE', '1ero': 9.7, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 10.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904-231', 'Alumno': 'MARTINEZ TAVIRA ANA VICTORIA', '1ero': 9.3, '2do': 10.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 10.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR1C'}
# exito con la inserción {'Matricula': 'ZL1-904
0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR2B'}
# exito con la inserción {'Matricula': 'ZL1-904-204', 'Alumno': 'VILLA LOPEZ KARLA VIANEY', '1ero': 7.9, '2do': 8.0, '3ero': 10.0, 'cualitativo': 0.0, 'Promedio': 9.0, 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Grupo': '1ZLTUR2B'}
# {'Plantel': '', 'Licenciatura': 'Turismo', 'Profesor': 'Fernando Ernesto Villegas Alvarez', 'Asignatura': 'Informática', 'Clave': 'LTM103', 'Grupo': '1ZLTUR2B', 'alumnos': 35}
# leidos de la hoja:  35
# Insertados:  35
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:54: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.

# %%
#Extraigo todos los datos a como fueron subidos en la base de datos
Calificaciones_df = pandito.DataFrame(coleccion.find())

# %%
#impresion de los datos que tenemos
Calificaciones_df.head()
# Out:
#    1ero  2do  3ero                          Alumno        Asignatura  \
# 0   9.0  7.0  10.0  ALCALA CONSUELOS DANIEL ISACAR  Administración I
# 1   9.0  8.0  10.0   ALCANTARA GARCIA LUIS EDUARDO  Administración I
# 2   6.0  8.0  10.0           ARROYO VILLEGAS CESAR  Administración I
# 3  10.0  6.0  10.0         BELTRAN GARCILITA EDRIK  Administración I
# 4  10.0  9.0  10.0  CAHUANTZI MARTINEZ TANIA PAOLA  Administración I
#
#       Grupo                            Licenciatura    Matricula  \
# 0  1ZLSIS1A  Ingenieria en Sistemas Computacionales  ZL1-901-041
# 1  1ZLSIS1A  Ingenieria en Sistemas Computacionales  ZL1-901-088
# 2  1ZLSIS1A  Ingenieria en Sistemas Computacionales  ZL1-901-013
# 3  1ZLSIS1A  Ingenieria en Sistemas Computacionales  ZL1-901-007
# 4  1ZLSIS1A  Ingenieria en Sistemas Computacionales  ZL1-901-005
#
#                      Profesor  Promedio                       _id  cualitativo
# 0  Alejandro Barrera Trevilla       9.0  5d28af2732f34d2da29ad067          0.0
# 1  Alejandro Barrera Trevilla       9.0  5d28af2832f34d2da29ad068          0.0
# 2  Alejandro Barrera Trevilla       8.0  5d28af2832f34d2da29ad069          0.0
# 3  Alejandro Barrera Trevilla       9.0  5d28af2832f34d2da29ad06a          0.0
# 4  Alejandro Barrera Trevilla      10.0  5d28af2832f34d2da29ad06b          0.0

# %%
#Muestro los tipos de datos de las columnas del dataframe
Calificaciones_df.dtypes
# Out:
# 1ero            float64
# 2do             float64
# 3ero            float64
# Alumno           object
# Asignatura       object
# Grupo            object
# Licenciatura     object
# Matricula        object
# Profesor         object
# Promedio        float64
# _id              object
# cualitativo     float64
# dtype: object

# %%
#Guardo el dataframe original que se ha descargado de la base de datos
Calificaciones_df.to_csv("findb.csv", index = False)

# %%
#La columna _id, es el recurso de identificador unico de mongoDB, podemos eliminar esa columna ya que no nos sirve para lo que queremos hacer
Cdf = Calificaciones_df.drop("_id", axis=1)

# %%
Cdf.columns
# Out:
# Index(['1ero', '2do', '3ero', 'Alumno', 'Asignatura', 'Grupo', 'Licenciatura',
#        'Matricula', 'Profesor', 'Promedio', 'cualitativo'],
#       dtype='object')

# %%
#quiero ver si hay registros duplicados pero no me deja revisar la ipmresion de los elementos
Cdf.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2708    False
# 2709    False
# 2710    False
# 2711    False
# 2712    False
# 2713    False
# 2714    False
# 2715    False
# 2716    False
# 2717    False
# 2718    False
# 2719    False
# 2720    False
# 2721    False
# 2722    False
# 2723    False
# 2724    False
# 2725    False
# 2726    False
# 2727    False
# 2728    False
# 2729    False
# 2730    False
# 2731    False
# 2732    False
# 2733    False
# 2734    False
# 2735    False
# 2736    False
# 2737    False
# Length: 2738, dtype: bool

# %%
# la longitud es de 2738 elementos no se ve si hay duplicados asi que abusando de la suerte, y de los comandos que se proporcionan en pandas, 
# entonces eliminare los duplicados esperndo una revision de estos mismos
Cdf.drop_duplicates()
# Out:
#        1ero   2do  3ero                              Alumno        Asignatura  \
# 0      9.00   7.0  10.0      ALCALA CONSUELOS DANIEL ISACAR  Administración I
# 1      9.00   8.0  10.0       ALCANTARA GARCIA LUIS EDUARDO  Administración I
# 2      6.00   8.0  10.0               ARROYO VILLEGAS CESAR  Administración I
# 3     10.00   6.0  10.0             BELTRAN GARCILITA EDRIK  Administración I
# 4     10.00   9.0  10.0      CAHUANTZI MARTINEZ TANIA PAOLA  Administración I
# 5      6.00   7.0  10.0    CONTRERAS GARRIDO EDUARDO DANIEL  Administración I
# 6     10.00   7.0  10.0           ELIZARRARAS GARCIA ANDRES  Administración I
# 7     10.00   6.0  10.0            ESPINOZA AYALA HERIBERTO  Administración I
# 8      8.00   8.0  10.0             ESTEVA MARTINEZ JOCELYN  Administración I
# 9     10.00   8.0  10.0     GUERRERO RODRIGUEZ MIGUEL ANGEL  Administración I
# 10     0.00   0.0   0.0                GUZMAN ALVORES EDWIN  Administración I
# 11    10.00   8.0  10.0          HERNANDEZ ARREDONDO ISRAEL  Administración I
# 12     6.00   7.0  10.0       HERNANDEZ SEGOVIA SERGIO ALAN  Administración I
# 13     6.00   6.0  10.0          JIMENEZ AMARO MARIO ISRAEL  Administración I
# 14     0.00   0.0   0.0            LICONA VILLALOBOS DAMIAN  Administración I
# 15     8.00   7.0  10.0            MARQUEZ RUFINO HUGO IVAN  Administración I
# 16     0.00   0.0   0.0               MARTINEZ ROJAS ISRAEL  Administración I
# 17    10.00   8.0  10.0               MEDINA GARCES ELEAZAR  Administración I
# 18    10.00   9.0  10.0            MENDOZA CRUZ ALEXIS GAEL  Administración I
# 19     0.00   0.0   0.0              MERIDA GONZALEZ DANIEL  Administración I
# 20    10.00   8.0  10.0               MORALES GONZALEZ ALAN  Administración I
# 21    10.00   9.0  10.0   MUJICA GUTIERREZ CINTHYA GABRIELA  Administración I
# 22     6.00   8.0  10.0  NAVARRETE CASAS CHRISTOPHER JORDAN  Administración I
# 23     8.00   7.0  10.0              OCAMPO JARAMILLO KAREN  Administración I
# 24     7.00   0.0   0.0         ORTIZ MORALES KEVIN RODRIGO  Administración I
# 25     6.00   7.0   0.0        PEÑAFLOR BRITO FELIX ROBERTO  Administración I
# 26    10.00   9.0  10.0               PERALTA SILVA ROBERTO  Administración I
# 27     0.00   0.0   0.0        RAMIREZ SUAREZ CIELO DANIELA  Administración I
# 28     6.00   6.0   0.0     RODRIGUEZ VAZQUEZ LUIS FERNANDO  Administración I
# 29    10.00   0.0   0.0                ROSAS MENESES ADRIAN  Administración I
# ...     ...   ...   ...                                 ...               ...
# 2708   9.10  10.0  10.0              CABRERA VARGAS PAULINA       Informática
# 2709   9.60   8.0   0.0    CAMIZAO JURADO GUADALUPE DANIELA       Informática
# 2710   6.40   8.0  10.0     CASILLAS SALAZAR JAIRY ESTEFANY       Informática
Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2711  Fernando Ernesto Villegas Alvarez      10.0          0.0
# 2712  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2713  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2714  Fernando Ernesto Villegas Alvarez       6.0          0.0
# 2715  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2716  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2717  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2718  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2719  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2720  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2721  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2722  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2723  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2724  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2725  Fernando Ernesto Villegas Alvarez      10.0          1.0
# 2726  Fernando Ernesto Villegas Alvarez       5.0          0.0
# 2727  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2728  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2729  Fernando Ernesto Villegas Alvarez      10.0          0.0
# 2730  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2731  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2732  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2733  Fernando Ernesto Villegas Alvarez       9.0          0.0
# 2734  Fernando Ernesto Villegas Alvarez       8.0          0.0
# 2735  Fernando Ernesto Villegas Alvarez      10.0          0.0
# 2736  Fernando Ernesto Villegas Alvarez       5.0          0.0
# 2737  Fernando Ernesto Villegas Alvarez       9.0          0.0
#
# [2271 rows x 11 columns]

# %%
#La ejecucion del comando nos arroja 2271 filas entonces, si existian registros duplicados que se han eliminado

# %%
#Comencemos por ordenar las columnas
Cdf.columns
# Out:
# Index(['1ero', '2do', '3ero', 'Alumno', 'Asignatura', 'Grupo', 'Licenciatura',
#        'Matricula', 'Profesor', 'Promedio', 'cualitativo'],
#       dtype='object')

# %%
column_order = ['Licenciatura','Grupo','Matricula','Alumno','1ero', '2do', '3ero', 'Asignatura','Profesor', 'Promedio', 'cualitativo']
Cdf = Cdf[column_order]
Cdf.head()
#columnas ya ordenadas
# Out:
#                              Licenciatura     Grupo    Matricula  \
# 0  Ingenieria en Sistemas Computacionales  1ZLSIS1A  ZL1-901-041
# 1  Ingenieria en Sistemas Computacionales  1ZLSIS1A  ZL1-901-088
# 2  Ingenieria en Sistemas Computacionales  1ZLSIS1A  ZL1-901-013
# 3  Ingenieria en Sistemas Computacionales  1ZLSIS1A  ZL1-901-007
# 4  Ingenieria en Sistemas Computacionales  1ZLSIS1A  ZL1-901-005
#
#                            Alumno  1ero  2do  3ero        Asignatura  \
# 0  ALCALA CONSUELOS DANIEL ISACAR   9.0  7.0  10.0  Administración I
# 1   ALCANTARA GARCIA LUIS EDUARDO   9.0  8.0  10.0  Administración I
# 2           ARROYO VILLEGAS CESAR   6.0  8.0  10.0  Administración I
# 3         BELTRAN GARCILITA EDRIK  10.0  6.0  10.0  Administración I
# 4  CAHUANTZI MARTINEZ TANIA PAOLA  10.0  9.0  10.0  Administración I
#
#                      Profesor  Promedio  cualitativo
# 0  Alejandro Barrera Trevilla       9.0          0.0
# 1  Alejandro Barrera Trevilla       9.0          0.0
# 2  Alejandro Barrera Trevilla       8.0          0.0
# 3  Alejandro Barrera Trevilla       9.0          0.0
# 4  Alejandro Barrera Trevilla      10.0          0.0

# %%
#Obtendré los sets de licenciaturas, grupos asignaturas, profesor
lic= set(Cdf['Licenciatura'])
gpo= set(Cdf['Grupo'])
materias= set(Cdf['Asignatura'])
docente= set(Cdf['Profesor'])
print("lic", lic,"\n")
print("gpo", gpo,"\n")
print("materias", materias,"\n")
print("docente", docente,"\n")
# Out:
# lic {'Administración de Empresas', 'Turismo', 'Diseño Gráfico', 'Ingenieria en Sistemas Computacionales', 'Ingeniería en Sistemas Computacionales', 'Contaduria y Finanzas'}
#
# gpo {'1ZLSIS1B', '1ZLSIS1C', '7ZLSIS1A', '1ZLCON1B', '4ZLSIS1B', '1ZLADM2B', '1ZLTUR1C', '1ZLTUR1A', '1ZLSIS2A', '1ZLDIS1A', '4ZLSIS2A', '1ZLDIS1B', '4ZLSIS1A', '7ZLSIS2A', '1ZLTUR2A', '1ZLSIS1A', '1ZLTUR1B', '1ZLDIS2A', '1ZLSIS2B', '1ZLDIS2B', '7ZLSIS1B', '1ZLADM2A', '1ZLTUR2B'}
#
# materias {'Sistemas Operativos II', 'Programación Estructurada y Orientada a Objetos', 'Administración I', 'Métodos Numéricos', 'Arquitectura de Computadoras', 'Estructura de Datos II', 'Electricidad y Magenistmo', 'Computación ', 'Analisis de Sistemas y Señales', 'Cálculo', 'Contabilidad II', 'Redes de Computadoras', 'Electricidad y Magnetismo', 'Geometría Analítica', 'Álgebra', 'Memorias y Periféricos', 'Dinámica de Sistemas Físicos', 'Fisica', 'Sistemas de Información II', 'Informática', 'Inglés', 'Metodología de la Investigación'}
#
# docente {'Jaime Minor Gómez', 'Alejandro Barrera Trevilla', 'Lilia Angelica Muñoz Guereca', 'Gerardo Arias Hernández', 'Delia Azucena Lienzo Vázquez', 'Maria de la Gracia Barquero Díaz Barriga ', 'Jose Angel Barrientos Lopez', 'Ingrid Guadalupe Amezcua García', 'Juan Angel Calvillo Perez', 'Isabel Alejandra González Quintero Marmol', 'Martha Gabriela López Rodríguez', 'Miguel Angel Pi Cobian ', 'Jose Guadalupe Sánchez Hernández', 'Fernando Ernesto Villegas Alvarez', 'Adriana Guadalupe Islas Ortega'}

# %%
#tengo valores que no estan bien escritos en lic, tengo que localizarlos y reemplazarlos
test = Cdf[(Cdf['Licenciatura']=='Ingenieria en Sistemas Computacionales')]
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
Cdf.loc[(Cdf['Licenciatura']=='Ingenieria en Sistemas Computacionales')] = 'Ingeniería en Sistemas Computacionales'

# %%
lic= set(Cdf['Licenciatura'])
print("lic", lic,"\n")
# Out:
# lic {'Administración de Empresas', 'Turismo', 'Diseño Gráfico', 'Ingeniería en Sistemas Computacionales', 'Contaduria y Finanzas'}

# %%
#Aparentemente ya todo se encuentra bien, entonces pasaremos a separar por los diferentes dataframes que nos piden
#Comenzaré por carreras

# %%
Administracion = Cdf[(Cdf['Licenciatura']=='Administración de Empresas')]
Turismo = Cdf[(Cdf['Licenciatura']=='Turismo')]
Diseño = Cdf[(Cdf['Licenciatura']=='Diseño Gráfico')]
Sistemas = Cdf[(Cdf['Licenciatura']=='Ingeniería en Sistemas Computacionales')]
Conta = Cdf[(Cdf['Licenciatura']=='Contaduria y Finanzas')]

Sistemas.dtypes

# %%
Sistemas['Promedio']
# Out:
# 0       Ingeniería en Sistemas Computacionales
# 1       Ingeniería en Sistemas Computacionales
# 2       Ingeniería en Sistemas Computacionales
# 3       Ingeniería en Sistemas Computacionales
# 4       Ingeniería en Sistemas Computacionales
# 5       Ingeniería en Sistemas Computacionales
# 6       Ingeniería en Sistemas Computacionales
# 7       Ingeniería en Sistemas Computacionales
# 8       Ingeniería en Sistemas Computacionales
# 9       Ingeniería en Sistemas Computacionales
# 10      Ingeniería en Sistemas Computacionales
# 11      Ingeniería en Sistemas Computacionales
# 12      Ingeniería en Sistemas Computacionales
# 13      Ingeniería en Sistemas Computacionales
# 14      Ingeniería en Sistemas Computacionales
# 15      Ingeniería en Sistemas Computacionales
# 16      Ingeniería en Sistemas Computacionales
# 17      Ingeniería en Sistemas Computacionales
# 18      Ingeniería en Sistemas Computacionales
# 19      Ingeniería en Sistemas Computacionales
# 20      Ingeniería en Sistemas Computacionales
# 21      Ingeniería en Sistemas Computacionales
# 22      Ingeniería en Sistemas Computacionales
# 23      Ingeniería en Sistemas Computacionales
# 24      Ingeniería en Sistemas Computacionales
# 25      Ingeniería en Sistemas Computacionales
# 26      Ingeniería en Sistemas Computacionales
# 27      Ingeniería en Sistemas Computacionales
# 28      Ingeniería en Sistemas Computacionales
# 29      Ingeniería en Sistemas Computacionales
#                          ...
# 1735                                         9
# 1736                                         7
# 1737                                         9
# 1738                                         5
# 1739                                         8
# 1740                                         7
# 1741                                         8
# 1742                                         7
# 1743                                         8
# 1744                                         8
# 1745                                         5
# 1746                                         9
# 1747                                         7
# 1748                                        10
# 1749                                        10
# 1750                                         8
# 1751                                         9
# 1752                                        10
# 1753                                         9
# 1754                                        10
# 1755                                         6
# 1756                                        10
# 1757                                         8
# 1758                                         8
# 1759                                         7
# 1760                                         9
# 1761                                        10
# 1762                                         6
# 1763                                        10
# 1764                                         9
# Name: Promedio, Length: 1765, dtype: object

# %%
print("El promedio de la carrera de Administrción de Empresas es: ", np.mean(Administracion['Promedio']))
print("El promedio de la carrera de Turismo es: ", np.mean(Turismo['Promedio']))
print("El promedio de la carrera de Diseño Gráfico es: ", np.mean(Diseño['Promedio']))
print("El promedio de la carrera de Sistemas: ", np.mean(Sistemas['Promedio']))
print("El promedio de la carrera de Contaduria y Finanzas es: ", np.mean(Conta['Promedio']))
# Out:
# El promedio de la carrera de Administrción de Empresas es:  7.818181818181818
# El promedio de la carrera de Turismo es:  7.9734513274336285
# El promedio de la carrera de Diseño Gráfico es:  7.126373626373627
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# c:\program files\python37\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#
# c:\program files\python37\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: can only concatenate str (not "float") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-00fd68ac9b68> in <module>
#       2 print("El promedio de la carrera de Turismo es: ",np.mean(Turismo['Promedio']))
#       3 print("El promedio de la carrera de Diseño Gráfico es: ",np.mean(Diseño['Promedio']))
# ----> 4 print("El promedio de la carrera de Sistemas: ",np.mean(Sistemas['Promedio']))
#       5 print("El promedio de la carrera de Contaduria y Finanzas es: ", np.mean(Conta['Promedio']))
#
# c:\program files\python37\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3113             pass
#    3114         else:
# -> 3115             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
#
# c:\program files\python37\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# c:\program files\python37\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# c:\program files\python37\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# c:\program files\python37\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     128             except Exception:
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#     132                     # we want to transform an object array
#
# c:\program files\python37\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     477         dtype_count = dtype
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#     481     if axis is not None and getattr(the_sum, 'ndim', False):
#
# c:\program files\python37\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "float") to str
