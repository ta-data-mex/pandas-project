# %%
#primero importamos las librerias a usar

import pandas as pd

# %%
#previamente desde el sitio descargamos la base de datos como un .csv que ya esta adjuntado para poder usarlo offline
#aqui vamos a abrir nuestra base de datos y transformarla para poder iniciar a trabajar en ella
songs = pd.read_csv('Top_1_000_Songs_To_Hear_Before_You_Die.csv')

# %%
#transformamos la base de datos en un data frame para poder trabajar mejor con ella

song_df = pd.DataFrame(songs)

# %%
#se revisa la cantidad de datos nulos de la lista de 994 elementos para decidir que se hara con ella

songnull = song_df.isnull().sum()
songnull[songnull > 0]
# Out:
# SPOTIFY_URL    222
# dtype: int64

# %%
#eliminamos la columna de SPOTIFY_URL ya que no se como agregar los urls de 22 canciones de manera eficiente

song_df.drop(['SPOTIFY_URL'], axis='columns', inplace=True)

# %%
#aqui nada mas revisamos que la columna de las 994 canciones y vemos que todos los elementos son correctos

song_df
# Out:
#            THEME                                           TITLE  \
# 0           Love                                The Look of Love
# 1           Love                                     The Shining
# 2           Love                                  God Only Knows
# 3           Love                                 Good Vibrations
# 4           Love                             Wouldn’t It Be Nice
# 5           Love                               Eight Days a Week
# 6           Love                                            Girl
# 7           Love                        I Want to Hold Your Hand
# 8           Love                                   She Loves You
# 9           Love                                       Something
# 10          Love              With a Little Help from My Friends
# 11          Love                                Song for Whoever
# 12          Love                          How Deep is Your Love?
# ...

# %%
#aqui ya subimos el archivo como un CSV y le cambiamos el nombre para indicar que son 994 y no 1000 canciones

song_df.to_csv('Top_994_Songs_To_Hear_Before_You_Die.csv', index=False)

# %%
#Aqui decidimos revisar cuantas canciones por tema hay, (modificando THEME podemos revisar los diferentes artistas o los años)

theme = pd.value_counts(songs["THEME"])
theme
# Out:
# Party songs             162
# Heartbreak              145
# People and places       145
# Politics and protest    141
# Love                    139
# Sex                     131
# Life and death          131
# Name: THEME, dtype: int64

# %%
#Aqui filtramos las canciones por tema Heartbreak (podemos cambiarlos por lo que sea y buscar lo que nos interese)

songheart = songs[(songs["THEME"] == 'Heartbreak')]
songheart
# Out:
#           THEME                                              TITLE  \
# 139  Heartbreak                               Tears Are Not Enough
# 140  Heartbreak                            The Winner Takes It All
# 141  Heartbreak                      Call Me on Your Way Back Home
# 142  Heartbreak                                         Never Ever
# 143  Heartbreak                           Please Give Me Something
# 144  Heartbreak                                        Without You
# 145  Heartbreak                                  Diamonds and Rust
# 146  Heartbreak                  You’ve Got to Hide Your Love Away
# 147  Heartbreak                           The Boy Done Wrong Again
# 148  Heartbreak                                     Heart of Glass
# 149  Heartbreak                                 One Way Or Another
# 150  Heartbreak                                              Flume
# 151  Heartbreak                                Bed is For Sleeping
# ...

# %%
#aqui sacamos los años de la cancion mas vieja y la cancion mas nueva

songsx = songs[['YEAR']].max(axis=0)
songsy = songs[['YEAR']].min(axis=0)
print('La cancion mas antigua es del: ', songsy)
print('La cancion mas actual es del: ', songsx);
# Out:
# La cancion mas antigua es del:  YEAR    1916
# dtype: int64
# La cancion mas actual es del:  YEAR    2008
# dtype: int64

# %%
#para futuras observaciones acomode canciones por año y asi uno podria evitarse el paso de solo pedir maximos y minimos

yearsort = song_df.sort_values(by='YEAR', ascending=True)
yearsort
# Out:
#                     THEME                                              TITLE  \
# 303     People and places                                          Jerusalem
# 377     People and places                         Things Are Worse in Russia
# 380     People and places                                       Stack O’ Lee
# 540                   Sex                                    Empty Bed Blues
# 91                   Love                    Let’s Do It, Let’s Fall in Love
# 705        Life and death                           St James Infirmary Blues
# 822        Life and death                                 Frankie and Johnny
# 405     People and places                                        T for Texas
# 564  Politics and protest            (What Did I Do To Be So) Black And Blue
# 655  Politics and protest      How Can a Poor Man Stand Such Times and Live?
# 201            Heartbreak                                 Devil Got My Woman
# ...
