# %%
#1. Através de import obtuve la librería de pandas y con pd.read_cvs se abrió y pude leer el archivo de Spotify en la computadora. 
import pandas as pd

data = pd.read_csv('Top_1_000_Songs_To_Hear_Before_You_Die.csv')
data
# Out:
#            THEME                                           TITLE  \
# 0           Love                                The Look of Love
# 1           Love                                     The Shining
# 2           Love                                  God Only Knows
# 3           Love                                 Good Vibrations
# 4           Love                             Wouldn’t It Be Nice
# 5           Love                               Eight Days a Week
# 6           Love                                            Girl
# 7           Love                        I Want to Hold Your Hand
# 8           Love                                   She Loves You
# 9           Love                                       Something
# 10          Love              With a Little Help from My Friends
# 11          Love                                Song for Whoever
# 12          Love                          How Deep is Your Love?
# ...

# %%
#2. Hice un data frame de mi base de datos con el metodo pd.DataFrame.
data = pd.DataFrame(data)

# %%
#3. Utilicé el método data.dtypes para visualizar el tipo de valores que contiene mi Data Frame.
data.dtypes
# Out:
# THEME          object
# TITLE          object
# ARTIST         object
# YEAR            int64
# SPOTIFY_URL    object
# dtype: object

# %%
#4. Utilice el método data.columns para visualizar el nombre de las columnas.
data.columns
# Out:
# Index(['THEME', 'TITLE', 'ARTIST', 'YEAR', 'SPOTIFY_URL'], dtype='object')

# %%
#5. Utilicé el método value_counts para contabilizar el número de canciones que salieron por año.  
year1 = pd.value_counts(data['YEAR'])
year1
# Out:
# 1968    39
# 1966    37
# 1979    34
# 1965    33
# 1967    33
# 1969    31
# 1971    30
# 1974    27
# 1977    27
# 1972    27
# 1964    27
# 1978    25
# 1980    25
# 1983    25
# 1973    24
# 1975    23
# 1970    23
# 1984    22
# 1981    19
# 2008    19
# 1989    19
# 1985    18
# 1987    18
# 1982    18
# 1994    18
# 1976    18
# 1986    17
# 1963    17
# 2007    16
# 1988    15
#         ..
# 2004     9
# 1997     8
# 1998     7
# 1962     7
# 2001     7
# 1996     7
# 1958     6
# 1928     6
# 1960     5
# 1954     4
# 1955     3
# 1951     3
# 1957     3
# 1939     3
# 1950     2
# 1946     2
# 1944     2
# 1941     2
# 1938     2
# 1932     2
# 1931     2
# 1929     2
# 1949     1
# 1940     1
# 1953     1
# 1936     1
# 1935     1
# 1952     1
# 1922     1
# 1916     1
# Name: YEAR, Length: 74, dtype: int64

# %%
#6. Utilicé value_counts para visualizar el número de canciones que tiene cada artista en el Data Frame.
artist1 = pd.value_counts(data['ARTIST'])
artist1
# Out:
# Bob Dylan                             24
# The Beatles                           19
# David Bowie                            9
# Randy Newman                           8
# The Rolling Stones                     8
# Prince                                 6
# The Beach Boys                         6
# Elvis Presley                          6
# Madonna                                6
# Frank Sinatra                          6
# Marvin Gaye                            6
# The Kinks                              6
# Neil Young                             5
# Al Green                               5
# Tom Waits                              5
# Elvis Costello and the Attractions     5
# The Supremes                           5
# The Clash                              5
# U2                                     5
# Johnny Cash                            5
# Chuck Berry                            5
# The Smiths                             5
# Kate Bush                              5
# ...

# %%
# 7. Utilicé value_counts para visualizar cuántas canciones existen en la columna "THEME" y así mismo pude visualizar cuántas categorías existen en esta columna. 
theme1 = pd.value_counts(data['THEME'])
theme1
# Out:
# Party songs             162
# Heartbreak              145
# People and places       145
# Politics and protest    141
# Love                    139
# Sex                     131
# Life and death          131
# Name: THEME, dtype: int64

# %%
#8. NULL me ayudó para visualizar en qué columnas existían valores nulos y a cuantificarlos.
null_columns = data.isnull().sum()
null_columns[null_columns > 0]
# Out:
# SPOTIFY_URL    222
# dtype: int64

# %%
#9. Con el método .fillna rellene los valores vacios con un guión ("-"), pensé que era lo mejor puesto que faltaban las URL pero las canciones si están dentro de la base de datos.
data[['SPOTIFY_URL']] = data[['SPOTIFY_URL']].fillna("-")
data
# Out:
#            THEME                                           TITLE  \
# 0           Love                                The Look of Love
# 1           Love                                     The Shining
# 2           Love                                  God Only Knows
# 3           Love                                 Good Vibrations
# 4           Love                             Wouldn’t It Be Nice
# 5           Love                               Eight Days a Week
# 6           Love                                            Girl
# 7           Love                        I Want to Hold Your Hand
# 8           Love                                   She Loves You
# 9           Love                                       Something
# 10          Love              With a Little Help from My Friends
# 11          Love                                Song for Whoever
# 12          Love                          How Deep is Your Love?
# ...

# %%
#10. Con el método column_order reordené las columnas puesto que de la forma en la que estaban originalmente no resultaba atactivo en cuanto a su visualización
column_order = ['ARTIST','TITLE','YEAR','THEME','SPOTIFY_URL']
datac = data[column_order]
datac.head(3)
# Out:
#             ARTIST             TITLE  YEAR THEME  \
# 0              ABC  The Look of Love  1982  Love
# 1  Badly Drawn Boy       The Shining  2000  Love
# 2   The Beach Boys    God Only Knows  1966  Love
#
#                                          SPOTIFY_URL
# 0  http://open.spotify.com/track/78j3qTBdzcIiT3eS...
# 1  http://open.spotify.com/track/2PojSoZ94AIzp7fs...
# 2  http://open.spotify.com/track/0ObrXLrfrqJUNc8R...

# %%
#11. El método filtered me ayudó para encontrar más facilmente a un artista, en un año y en un tema en específico de todo mi universo de datos.
filtered = datac[(data['THEME']=='Love') &  
                (data['YEAR']>= 1950) & 
                (data['ARTIST'] == 'The Beatles')]
filtered
# Out:
#          ARTIST                               TITLE  YEAR THEME SPOTIFY_URL
# 5   The Beatles                   Eight Days a Week  1964  Love           -
# 6   The Beatles                                Girl  1965  Love           -
# 7   The Beatles            I Want to Hold Your Hand  1963  Love           -
# 8   The Beatles                       She Loves You  1963  Love           -
# 9   The Beatles                           Something  1969  Love           -
# 10  The Beatles  With a Little Help from My Friends  1967  Love           -

# %%
#12. Con el método min y max pude sacar de la base de datos el año de la canción más nueva y de la más antigua.
old_song = data[['YEAR']].min(axis=0)
new_song = data[['YEAR']].max(axis=0)
print('Canción más antigua: ', old_song)

print('Canción más nueva: ', new_song)
# Out:
# Canción más antigua:  YEAR    1916
# dtype: int64
# Canción más nueva:  YEAR    2008
# dtype: int64

# %%
#13. Con el método sort.values puede ordenar de manera ascendente el nombre de los valores de la columna "ARTISTS".
datac.sort_values(by=['ARTIST'], ascending = True)
# Out:
#                                                ARTIST  \
# 561                                               !!!
# 713                           (Don’t Fear) The Reaper
# 833                                         808 State
# 98                                         A R Rahman
# 0                                                 ABC
# 139                                               ABC
# 835                                             AC/DC
# 432                                             AC/DC
# 842                                               ATB
# 430                                           Aaliyah
# 431                                              Abba
# 140                                              Abba
# 834                                              Abba
# 702                                       Abyssinians
# 703                                         Aerosmith
# 433                                         Aerosmith
# ...

# %%
#14. Utilice el método de "concat" (concatenación de fila) para juntar dos categorías de datos de la misma columna, en este caso ARTIST.
The_B = datac[datac['ARTIST']=='The Beatles']
Bob_Dylan = datac[datac['ARTIST']=='Bob Dylan']

BobD_The_B = pd.concat([The_B,Bob_Dylan], axis=0)

BobD_The_B.head(20)
# Out:
#           ARTIST                                  TITLE  YEAR  \
# 5    The Beatles                      Eight Days a Week  1964
# 6    The Beatles                                   Girl  1965
# 7    The Beatles               I Want to Hold Your Hand  1963
# 8    The Beatles                          She Loves You  1963
# 9    The Beatles                              Something  1969
# 10   The Beatles     With a Little Help from My Friends  1967
# 146  The Beatles      You’ve Got to Hide Your Love Away  1965
# 292  The Beatles                          Eleanor Rigby  1966
# 293  The Beatles                          Doctor Robert  1966
# 294  The Beatles                           Drive My Car  1965
# 295  The Beatles                             Penny Lane  1967
# 296  The Beatles                     She’s Leaving Home  1967
# 297  The Beatles              Strawberry Fields Forever  1967
# 437  The Beatles                           Another Girl  1965
# ...

# %%
#15. Utilicé el método melt para ir viendo por artista y año el tipo de categoría que tenían de la columna THEME
melted = pd.melt(datac, id_vars=['ARTIST','YEAR'], 
                 value_vars=['THEME'])
melted.head(10)

# %%
#16. Exportar a un nuevo archivo CSV

datac.to_csv('Top_1_000_Songs_To_Hear_Before_You_DieV2.csv', index=False)
